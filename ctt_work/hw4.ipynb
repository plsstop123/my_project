# %%
c = input("Nhập một ký tự (a-z) hoặc (A-Z)")
if c.isalpha():
    print(f"{c} là ký tự alphabet.")
else :
    print(f"{c} không phải là ký tự alphabet")
# Out:
# a là ký tự alphabet.
